# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# (**Vincent Cannady**)
# (Cyber Security Engineer)

# %% [markdown]
# (*I am interested in data science because I want to store, manage, and categorize all vulnerabilities my company have experienced*)
# (*The knowledge of which vulnerabilities are the most prevelant in our networks is very important to our company*)

# %% [markdown]
# ### Adding 100 + 100

# %%
(100 + 100)
# Out:
# 200

# %% [markdown]
# <ul><li>1st Project</li><li>2nd Notebook</li></ul>
# <ol><li>you</li><li>me</li><li>we</li></ol>
# <a href="https://www.learnpython.org/">Best Websie to Learn Python</a>
